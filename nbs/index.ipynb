# %%
#| hide
from demystifyopenclaw.core import *

# %% [markdown]
# # demystifyopenclaw
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install demystifyopenclaw in Development mode

# %% [markdown]
# ```sh
# # make sure demystifyopenclaw package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to demystifyopenclaw
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ninjalabo/demystifyopenclaw.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ninjalabo demystifyopenclaw
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install demystifyopenclaw
# ```
#
#
# [repo]: https://github.com/ninjalabo/demystifyopenclaw
# [docs]: https://ninjalabo.github.io/demystifyopenclaw/
# [pypi]: https://pypi.org/project/demystifyopenclaw/
# [conda]: https://anaconda.org/ninjalabo/demystifyopenclaw

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ninjalabo/demystifyopenclaw
# [docs]: https://ninjalabo.github.io/demystifyopenclaw/
# [pypi]: https://pypi.org/project/demystifyopenclaw/
# [conda]: https://anaconda.org/ninjalabo/demystifyopenclaw

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
